# %%
import pandas

# %%
data_frame = pandas.read_csv("/Users/claire/Desktop/eeg-data/museMonitor_2018-03-17--08-05-18.csv")

# %%
data_frame.head()
# Out:
#                  TimeStamp  Delta_TP9  Delta_AF7  Delta_AF8  Delta_TP10  \
# 0  2018-03-17 08:05:18.653        NaN        NaN        NaN         NaN
# 1  2018-03-17 08:05:19.465   1.240262  -0.263352   0.315376    1.492881
# 2  2018-03-17 08:05:20.401        NaN        NaN        NaN         NaN
# 3  2018-03-17 08:05:20.450   0.330001   0.402005  -0.088686    1.200459
# 4  2018-03-17 08:05:21.048        NaN        NaN        NaN         NaN
#
#    Theta_TP9  Theta_AF7  Theta_AF8  Theta_TP10  Alpha_TP9  \
# 0        NaN        NaN        NaN         NaN        NaN
# 1    0.89402  -0.420508   0.229114    1.025745   0.847474
# 2        NaN        NaN        NaN         NaN        NaN
# 3    0.61287  -0.123047  -0.519162    0.735113   0.426421
# 4        NaN        NaN        NaN         NaN        NaN
#
#            ...             Gyro_X     Gyro_Y     Gyro_Z  HeadBandOn  HSI_TP9  \
# 0          ...                NaN        NaN        NaN         NaN      NaN
# ...

# %%
cleaned_data_frame = data_frame[pandas.notnull(data_frame['Delta_TP9'])]

# %%
cleaned_data_frame.head()
# Out:
#                  TimeStamp  Delta_TP9  Delta_AF7  Delta_AF8  Delta_TP10  \
# 1  2018-03-17 08:05:19.465   1.240262  -0.263352   0.315376    1.492881
# 3  2018-03-17 08:05:20.450   0.330001   0.402005  -0.088686    1.200459
# 5  2018-03-17 08:05:21.461   0.381371   1.826566   1.111653    1.183077
# 6  2018-03-17 08:05:22.458   0.381371   1.865048   1.458918    1.183077
# 8  2018-03-17 08:05:23.451   1.637266   1.524364   1.464060    1.183077
#
#    Theta_TP9  Theta_AF7  Theta_AF8  Theta_TP10  Alpha_TP9    ...     \
# 1   0.894020  -0.420508   0.229114    1.025745   0.847474    ...
# 3   0.612870  -0.123047  -0.519162    0.735113   0.426421    ...
# 5   0.666607   0.391496   0.174356    0.920249   0.332401    ...
# 6   0.666607   0.184426   0.123051    0.920249   0.332401    ...
# 8   0.852797   0.566212   0.223700    0.920249   0.984424    ...
#
#       Gyro_X     Gyro_Y     Gyro_Z  HeadBandOn  HSI_TP9  HSI_AF7  HSI_AF8  \
# ...

# %%
cleaned_data_frame.reset_index().to_csv("/Users/claire/Desktop/eeg-data/cleaned_museMonitor_2018-03-17--08-05-18.csv", index=False, header=False)
